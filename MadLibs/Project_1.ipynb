# %%
name = input("Please Enter Your Name: ")
institute = input("Please Enter Your Institute Name (e.g. PIAIC, GIAIC, Saylani and other): ")
language = input("Please Enter Programming language (e.g. Python, JavaScript, TypeScript, NextJS and other): ")
background = input("Please Enter Your Educational Background: ")
fimiliar = input("Please Enter Your Programming Experience (e.g. Beginner, Intermediate or Expert): ")

print("Thank You for your Infomation, Your Store is Ready")
print(f"Assalam o alaikum, I am {name}. I am now Enroll IT Course in {institute}, I am lean {language} programming language at {institute} my education backgorund is {background} and I am {fimiliar} in programming. Thank you")
# Out:
# Please Enter Your Name: Fayyash
# Please Enter Your Institute Name (e.g. PIAIC, GIAIC, Saylani and other): PIAIC
# Please Enter Programming language: Python
# Please Enter Your Educational Background: Software
# Please Enter Your Programming Experience (e.g. Beginner, Intermediate or Expert): Expert
# Thank You for your Infomation, Your Store is Ready
# Assalam o alaikum, I am Fayyash. I am now Enroll IT Course in PIAIC, I am lean Python programming language at PIAIC my education is Software and I am Expert in programming. Thank you
